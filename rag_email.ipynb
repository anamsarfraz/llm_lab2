# %%
from dotenv import load_dotenv
load_dotenv()

from custom_gmail_reader import CustomGmailReader

# Instantiate the CustomGmailReader
loader = CustomGmailReader(
    query="",
    max_results=50,
    results_per_page=10,
    service=None
)

# Load the emails
documents = loader.load_data()

# Print email information
print(f"Number of documents: {len(documents)}")
for i, doc in enumerate(documents[:20]):
    print(f"Document {i+1}:")
    print(f"To: {doc.metadata.get('to', 'N/A')}")
    print(f"From: {doc.metadata.get('from', 'N/A')}")
    print(f"Subject: {doc.metadata.get('subject', 'N/A')}")
    print(f"Date: {doc.metadata.get('date', 'N/A')}")
    print(f"Content snippet: {doc.text[:1000]}...")
    print("=" * 50)
# Out:
# Number of documents: 50
# Document 1:
# To: Unum Sarfraz <anamsarfraz@gmail.com>
# From: Atoms <support@atoms.com>
# Subject: You have VIP access to the new MKBHD x Atoms collab.
# Date: Wed, 18 Sep 2024 01:06:16 +0000 (UTC)
# Content snippet: http://atoms.com
#
# https://atoms.com/products/model-251-lt-red-black/?=position1
#
# https://atoms.com/products/model-251-lt-red-black/?=position2
#
# https://atoms.com/products/model-251-lt-red-black/?=position2
#
# https://atoms.com/products/model-251-lt-red-black/?=position3
#
# https://atoms.com/products/model-251-lt-red-black/?=position4
#
# https://atoms.com/products/model-251-lt-blue-black
#
# https://atoms.com/products/model-251-lt-gray-black
#
# https://atoms.com/products/model-251-lt-red-black/?=position7
#
# https://atoms.com/products/model-251-lt-red-black?Gender=Men
#
# https://atoms.com/products/model-251-lt-red-black?Gender=Women
#
# https://atoms.com/products/model-251-lt-red-black/?=position8
#
# ...

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.retrievers import VectorIndexRetriever

# Create index
index = VectorStoreIndex.from_documents(documents)

# Create retriever
retriever = VectorIndexRetriever(index=index)

# Create query engine
query_engine = RetrieverQueryEngine(retriever=retriever)

# Example query
response = query_engine.query("Whats the summary of the email from the Rundown AI today?")
print(response)
# Out:
# The email from The Rundown AI today includes information about various advancements in AI technology, such as the launch of the Dream Machine API by Luma Labs, performance improvements for Gemini 1.5 Flash by Google, a Canadian study on AI's impact on reducing unexpected patient deaths, James Earl Jones allowing AI to replicate his Darth Vader voice, calls for international oversight on AI technology, and OpenAI's announcement of enhanced safety and security measures.

# %%
response = query_engine.query("What are the main news items they covered today?")
print(response)
# Out:
# The main news items covered today include NASA developing a new lunar time system for the Moon, OpenAI transitioning to a more traditional for-profit corporate structure, advancements in GPT-o1 capabilities, Facebook's challenges against Google in display ads, Amazon's chip design operations, United Airlines partnering with SpaceX for Starlink services, potential US shipping rule changes, and guidance for Engineering Managers during challenging times.

# %%
response = query_engine.query("Ok dont worry about the summary, what are the top news they mentioned?")
print(response)
# Out:
# Morning Brew reached over 4 million subscribers by deconstructing and rebuilding successful referral campaigns, such as its "Refer 50, Get a Mug" initiative. Google has announced confidential matching, a privacy-first tool that uses Trusted Execution Environments (TEEs) to secure first-party data for audience targeting and campaign measurement. Meta, Snapchat, and TikTok are teaming up to help detect and remove suicide and self-harm-related content in order to reduce exposure among at-risk users.

# %%
response = query_engine.query("Do they mention anything about slack?")
print(response)
# Out:
# Yes, the information provided discusses Slack's integration of AI agents and new workflows to enhance workplace productivity and streamline workflows.
